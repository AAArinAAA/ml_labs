# %% [markdown]
# # Лабораторная работа №8. Сверточные нейронные сети

# %% [markdown]
# ![i1Oi_GYhc-w.jpg](attachment:d140d7a4-8c5b-474f-a54a-56c1b59ac527.jpg)

# %% [markdown]
# # Импорт всего

# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as pl
from pathlib import Path
import os
import sys

sys.path.append(str(Path(os.getcwd()).parent))

# %%
train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
    "08_CNN/data/data", # путь к изображениям
    validation_split=0.2, # процент на тест
    subset="both", # берем и обучающую и тестовую выборку
    seed=42, # сид генератора случайных чисел
    image_size=(200,400), # целевой размер изображения (СНАЧАЛА ВЫСОТА, ПОТОМ ШИРИНА)
    batch_size=32, # размер пакета (батча)
)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 train_ds, test_ds = tf.keras.utils.image_dataset_from_directory(
#       2     "08_CNN/data/data", # путь к изображениям
#       3     validation_split=0.2, # процент на тест
#       4     subset="both", # берем и обучающую и тестовую выборку
#       5     seed=42, # сид генератора случайных чисел
#       6     image_size=(200,400), # целевой размер изображения (СНАЧАЛА ВЫСОТА, ПОТОМ ШИРИНА)
#       7     batch_size=32, # размер пакета (батча)
#       8 )
#
# File ~\Арина\учеба\labs\venv\Lib\site-packages\keras\src\utils\image_dataset.py:213, in image_dataset_from_directory(directory, labels, label_mode, class_names, color_mode, batch_size, image_size, shuffle, seed, validation_split, subset, interpolation, follow_links, crop_to_aspect_ratio, **kwargs)
#     211 if seed is None:
# ...
